# %%
# %load_ext autoreload
# %autoreload 2

# %%
from explanation.mojito2 import explainSamples,getMixedTriangles
import pandas as pd
from deeper.csv2dataset import get_cosine,text_to_vector
from deeper.DeepER import init_embeddings_index, init_embeddings_model, init_DeepER_model
from deeper.data import data2Inputs
from deeper.data import process_data_aligned
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %%
import ast 
df = pd.read_csv('rankings/beer_flippedneg_deepmatcher.csv')
df['alteredAttributes'] = df['alteredAttributes'].apply(ast.literal_eval)
df.iloc[0].alteredAttributes
# Out:
# ('Style',)

# %% [markdown]
# ## Experiment with triangles

# %%
def getMatchesMinCosSim(df,lprefix,rprefix,ignore_columns=['id','label']):
    cos_sim_list = []
    lattributes = [attr for attr in df.columns if(attr not in ignore_columns and attr.startswith(lprefix))]
    rattributes = [attr for attr in df.columns if(attr not in ignore_columns and attr.startswith(rprefix))]
    for i in range(len(df.index)):
        if df.iloc[i]['label']=='1':
            row = df.iloc[i]
            lrecord = " ".join(list(map(lambda attr:row[attr],lattributes)))
            rrecord = " ".join(list(map(lambda attr:row[attr],rattributes)))
            cos_sim_list.append(get_cosine(text_to_vector(lrecord),text_to_vector(rrecord)))
    return min(cos_sim_list)

# %%
train_walmart = pd.read_csv('datasets/walmart_amazon/train.csv',dtype=str).fillna("")
getMatchesMinCosSim(train_walmart,'ltable_','rtable_')
# Out:
# 0.11669000700233413

# %%
train_fodors = pd.read_csv('datasets/fodors_zagats/train.csv',dtype=str).fillna("")
getMatchesMinCosSim(train_fodors,'ltable_','rtable_')
# Out:
# 0.5669467095138409

# %%
walmart = pd.read_csv('datasets/walmart_amazon/walmart.csv',dtype=str)
amazon = pd.read_csv('datasets/walmart_amazon/amazon.csv',dtype=str)
triangles = getMixedTriangles(train_walmart,[walmart,amazon])
len(triangles)
# Out:
# 0

# %%
from explanation.sampleBuilder import prepareDataset
augmented_train = prepareDataset('datasets/walmart_amazon/','train.csv','walmart.csv','amazon.csv',
                                100)
# Out:
# 100%|██████████| 758/758 [01:56<00:00,  6.53it/s]

# %%
len(train_walmart),len(augmented_train)
# Out:
# (1476, 2017)

# %%
triangles = getMixedTriangles(augmented_train,[walmart,amazon])

# %%
triangles[0]
# Out:
# (id                                                        13477
#  brand                                                      Sony
#  modelno                                                DPW30R2H
#  title          Sony Dpw30R2H 1.4 Gb Camcorder 8Cm Dvd Rw Single
#  price                                                      3.49
#  dimensions                               3.9 x 3.5 x 0.3 inches
#  imageurl      http://ecx.images-amazon.com/images/I/51SDD1DW...
#  shipweight                                             1 pounds
#  Name: 13476, dtype: object,
#  id                                                         2354
#  brand                                                      Sony
#  modelno                                                DPW30R2H
#  title                  Sony DPW30R2H 1.4GB Camcorder 8cm DVD RW
#  price                                                      8.88
#  dimensions                              4.0 x 3.6 x 0.25 inches
#  imageurl      http://i.walmartimages.com/i/p/00/02/72/42/66/...
#  shipweight                                                 0.18
#  Name: 2353, dtype: object,
#  id                                                        16751
#  brand                                                  StarTech
#  modelno                                              PCI1S650PW
#  title         StarTech.com 1 Port PCI RS232 Powered Serial A...
#  price                                                     36.78
#  dimensions                               8.3 x 5.6 x 1.6 inches
#  imageurl      http://ecx.images-amazon.com/images/I/313%2B6i...
#  shipweight                                             1 pounds
#  Name: 16750, dtype: object,
#  'R-L-R')

# %%
def testTriangles(dataset,triangles):
    dataset_c = dataset.copy()
    dataset_c['ltable_id'] = list(map(lambda lrid:lrid.split("#")[0],dataset_c.id.values))
    dataset_c['rtable_id'] = list(map(lambda lrid:lrid.split("#")[1],dataset_c.id.values))
    positives = dataset_c[dataset_c.label=='1']
    negatives = dataset_c[dataset_c.label=='0']
    for triangle in triangles:
        provenance = triangle[3].split('-')
        if provenance[0]=='R' and provenance[1]=='L':
            pair1 = triangle[1]['id']+"#"+triangle[0]['id']
            pair2 = triangle[1]['id']+"#"+triangle[2]['id']
        else:
            pair1 = triangle[0]['id']+"#"+triangle[1]['id']
            pair2 = triangle[2]['id']+"#"+triangle[1]['id']
        if not(pair1 in positives.id.values and pair2 in negatives.id.values):
            print(pair1)
            print(pair2)

# %%
testTriangles(augmented_train,triangles)
# Out:
# 2354#13477
# 2354#16751
# 2258#8357
# 1164#8357
# 2258#8357
# 2258#2600
# 596#14870
# 1582#14870
# 596#14870
# 646#14870
# 82#17195
# 1582#17195
# 82#17195
# 539#17195
# 303#16642
# 1653#16642
# 303#16642
# 303#6769
# 1603#10609
# 1603#21372
# 1603#10609
# 1603#7132
# 1603#19808
# 1603#21372
# 1603#19808
# 1603#7132
# 1045#3010
# 2095#3010
# 1045#3010
# 1045#20512
# 1045#3010
# 1045#10512
# 330#7315
# 1371#7315
# 330#7315
# 219#7315
# 330#7315
# 79#7315
# 1672#20795
# 1672#19007
# 2137#19007
# 1672#19007
# 2137#19007
# 2276#19007
# 2137#19007
# 2261#19007
# 2137#19007
# 2137#9561
# 1188#5480
# 1188#18603
# 523#14015
# 523#17969
# 921#3247
# 1084#3247
# 921#3247
# 921#18882
# 1844#4901
# 1844#8674
# 2081#16296
# 390#16296
# 2081#16296
# 2081#9676
# 1523#21030
# 1523#17969
# 1523#1026
# 1523#17969
# 625#4040
# 625#6829
# 346#8387
# 346#16794
# 265#16641
# 265#15352
# 98#15905
# 1181#15905
# 98#15905
# 98#11242
# 1762#4577
# 89#4577
# 1762#4577
# 1762#12734
# 1762#4577
# 1762#12928
# 1762#12648
# 1793#12648
# 1762#12648
# 1762#12734
# 1762#12648
# 1762#12928
# 86#9497
# 86#15435
# 1287#16536
# 1287#21197
# 2197#19485
# 638#19485
# 2197#19485
# 560#19485
# 2197#19485
# 2197#18981
# 2197#17367
# 2197#18981
# 1546#21375
# 1546#6971
# 322#20698
# 844#20698
# 322#20698
# 1585#20698
# 322#20698
# 322#18468
# 322#20698
# 322#20729
# 322#20698
# 322#429
# 322#4630
# 322#18468
# 322#4630
# 322#20729
# 322#4630
# 322#429
# 298#15654
# 2143#15654
# 298#15654
# 298#11327
# 473#15368
# 2147#15368
# 473#15368
# 473#20018
# 1176#19246
# 1176#4815
# 984#18365
# 984#15143
# 1292#17830
# 896#17830
# 1292#17830
# 202#17830
# 1292#17830
# 1292#14195
# 770#6363
# 770#3060
# 145#7971
# 145#10333
# 168#15438
# 168#12882
# 1209#16936
# 1209#19912
# 1209#16936
# 1209#1226
# 1209#18171
# 1209#19912
# 1209#18171
# 1209#1226
# 54#17893
# 726#17893
# 54#17893
# 528#17893
# 54#17893
# 2539#17893
# 54#17893
# 54#11148
# 1908#10482
# 1908#17950
# 2409#5519
# 2409#11401
# 2409#5519
# 2409#13414
# 2409#6809
# 1974#6809
# 2409#6809
# 2409#11401
# 2409#6809
# 2409#13414
# 612#8430
# 612#17059
# 2550#19120
# 1778#19120
# 2550#19120
# 2550#8740
# 2483#19120
# 1778#19120
# 2483#19120
# 2483#124
# 2090#7049
# 2090#2556
# 482#14854
# 482#2367
# 482#14854
# 482#6847
# 482#987
# 482#2367
# 482#987
# 482#6847
# 786#10846
# 786#18949
# 1181#4538
# 16#4538
# 1181#4538
# 1181#15905
# 314#8871
# 207#8871
# 314#8871
# 1369#8871
# 314#8871
# 2428#8871
# 2089#22026
# 2089#13121
# 2089#22026
# 2089#14644
# 2089#17264
# 1614#17264
# 2089#17264
# 1707#17264
# 2089#17264
# 2089#13121
# 2089#17264
# 2089#14644
# 1886#2011
# 1886#5196
# 1687#17666
# 1687#15797
# 1687#17666
# 1687#5543
# 1687#20039
# 626#20039
# 1687#20039
# 1687#15797
# 1687#20039
# 1687#5543
# 21#16838
# 21#12001
# 2118#14558
# 661#14558
# 2118#14558
# 2118#4818
# 454#4893
# 454#17808
# 454#10900
# 454#17808
# 2202#17199
# 2202#20592
# 1505#4818
# 2118#4818
# 1505#4818
# 785#4818
# 1505#4818
# 4#4818
# 1505#4818
# 1505#4692
# 2152#7339
# 212#7339
# 2152#7339
# 2152#17918
# 1885#17579
# 1885#14936
# 2276#19663
# 2276#19007
# 1299#8456
# 1299#15273
# 1773#2223
# 1773#3741
# 2143#13935
# 2143#15654
# 2478#4885
# 2478#4815
# 2261#13723
# 2261#19007
# 192#11198
# 192#3781
# 1198#4815
# 1176#4815
# 1198#4815
# 2478#4815
# 1198#4815
# 1198#3088
# 626#18444
# 626#20039
# 1894#11121
# 2141#11121
# 1894#11121
# 1325#11121
# 1894#11121
# 1894#3163
# 1247#21595
# 1247#11439
# 1247#21595
# 1247#1881
# 1247#17192
# 1247#11439
# 1247#17192
# 1247#1881
# 723#12996
# 723#3754
# 1910#11285
# 529#11285
# 1910#11285
# 1910#15027
# 1910#20494
# 1910#15027
# 1253#9636
# 1253#10675
# 2053#6287
# 2053#15684
# 2189#2672
# 2189#12500
# 397#17849
# 397#8724
# 397#7145
# 397#8724
# 397#7150
# 397#8724
# 2104#2964
# 2104#2560
# 1196#5365
# 1196#14648
# 2038#8520
# 2038#21348
# 325#8520
# 325#15477
# 26#6985
# 26#19655
# 2380#265
# 2380#1419
# 2380#265
# 2380#16509
# 2380#10268
# 2380#1419
# 2380#10268
# 2380#16509
# 1984#6914
# 1619#6914
# 1984#6914
# 1984#4520
# 1512#4520
# 1984#4520
# 1512#4520
# 1512#21196
# 1103#7854
# 1103#1442
# 2194#5683
# 2194#10906
# 2194#5683
# 2194#20806
# 2194#9731
# 1627#9731
# 2194#9731
# 2194#10906
# 2194#9731
# 2194#20806
# 1149#16757
# 1149#15432
# 363#16308
# 363#3101
# 363#16308
# 363#14712
# 548#9296
# 548#10264
# 16#4283
# 16#4538
# 1502#5286
# 2091#5286
# 1502#5286
# 152#5286
# 2141#6966
# 2141#11121
# 2084#14540
# 2084#8687
# 1378#12162
# 1378#11117
# 2345#4985
# 2345#13584
# 2345#14945
# 2345#13584
# 2345#6971
# 1546#6971
# 2345#6971
# 2345#13584
# 1160#13110
# 1160#11710
# 1467#11642
# 2107#11642
# 1467#11642
# 1467#14207
# 1467#15576
# 607#15576
# 1467#15576
# 631#15576
# 1467#15576
# 1467#14207
# 2382#3483
# 2382#11720
# 2382#3483
# 2382#20355
# 1081#14455
# 1081#11690
# 2393#15894
# 2393#17952
# 160#9710
# 160#16991
# 688#20213
# 1685#20213
# 688#20213
# 688#7115
# 766#15416
# 2101#15416
# 766#15416
# 766#2839
# 766#15416
# 766#3105
# 1478#2433
# 1478#19585
# 1478#2433
# 1478#8243
# 799#6374
# 799#20386
# 834#18900
# 834#19842
# 1154#13246
# 1154#1646
# 1510#9333
# 2160#9333
# 1510#9333
# 1510#10103
# 347#8305
# 551#8305
# 347#8305
# 347#6109
# 2184#10974
# 2184#18102
# 726#16278
# 726#5250
# 726#16278
# 726#17893
# 726#16801
# 726#5250
# 726#16801
# 726#17893
# 1928#19027
# 1928#21804
# 1889#6730
# 1889#7146
# 1852#13349
# 1852#6217
# 1113#10801
# 484#10801
# 1113#10801
# 1113#8619
# 1851#17489
# 1851#3794
# 1902#10883
# 308#10883
# 177#4855
# 177#7901
# 219#5047
# 219#7315
# 1110#8092
# 1110#5629
# 1110#8092
# 1110#11414
# 1110#6058
# 1110#5629
# 1110#6058
# 1110#11414
# 1368#12147
# 1368#15110
# 1234#12408
# 1395#12408
# 1234#12408
# 1234#15684
# 1234#12408
# 1234#10647
# 1234#18429
# 149#18429
# 1234#18429
# 1234#15684
# 1234#18429
# 1234#10647
# 295#19912
# 1209#19912
# 295#19912
# 295#10374
# 2015#11741
# 2015#5940
# 2015#9457
# 2015#5940
# 156#3447
# 1777#3447
# 156#3447
# 156#12846
# 2544#2534
# 1312#2534
# 2544#2534
# 2544#21426
# 2544#2534
# 2544#10036
# 1932#11215
# 1932#11940
# 1607#18688
# 1607#6120
# 578#19368
# 1580#19368
# 578#19368
# 578#6131
# 578#19368
# 578#3026
# 578#21737
# 1120#21737
# 578#21737
# 578#6131
# 578#21737
# 578#3026
# 1695#3794
# 1851#3794
# 1695#3794
# 476#3794
# 1695#3794
# 1695#100
# 1695#3794
# 1695#19165
# 1695#3794
# 1695#2148
# 1695#11027
# 1695#100
# 1695#11027
# 1695#19165
# 1695#11027
# 1695#2148
# 1695#20398
# 1695#100
# 1695#20398
# 1695#19165
# 1695#20398
# 1695#2148
# 551#2556
# 2090#2556
# 551#2556
# 551#8305
# 1262#8267
# 1262#2868
# 1973#3594
# 1973#14931
# 1973#3594
# 1973#3314
# 1973#3591
# 1973#14931
# 1973#3591
# 1973#3314
# 598#22044
# 2395#22044
# 598#22044
# 598#20512
# 917#8911
# 917#20840
# 917#8911
# 917#10374
# 105#11792
# 105#17619
# 43#173
# 43#10131
# 1278#1881
# 1247#1881
# 1278#1881
# 1278#1929
# 1321#885
# 1321#9561
# 1321#885
# 1321#13883
# 1321#885
# 1321#10921
# 1904#10675
# 179#10675
# 1904#10675
# 1253#10675
# 1904#10675
# 27#10675
# 1904#10675
# 1904#10894
# 2504#20052
# 2504#11456
# 2504#20052
# 2504#12310
# 2504#20052
# 2504#11348
# 2051#21913
# 1476#21913
# 2051#21913
# 2051#5556
# 1614#17219
# 1614#17264
# 863#11819
# 863#18788
# 863#11819
# 863#15797
# 863#5783
# 863#18788
# 863#5783
# 863#15797
# 2277#12761
# 2277#8808
# 549#3415
# 549#11690
# 2156#4319
# 2156#12853
# 2156#4319
# 2156#17720
# 2156#4319
# 2156#17788
# 2156#17865
# 2156#12853
# 2156#17865
# 2156#17720
# 2156#17865
# 2156#17788
# 2156#4510
# 2156#12853
# 2156#4510
# 2156#17720
# 2156#4510
# 2156#17788
# 180#8546
# 659#8546
# 180#8546
# 180#15451
# 798#6509
# 798#20078
# 528#486
# 528#17893
# 132#5596
# 132#3146
# 1869#4495
# 1869#15826
# 2249#8369
# 609#8369
# 2249#8369
# 2257#8369
# 2249#8369
# 2249#10629
# 1283#1241
# 1283#15889
# 2133#7359
# 2133#1503
# 1296#6406
# 1296#5556
# 1629#6289
# 637#6289
# 1629#6289
# 1629#11393
# 1691#4227
# 87#4227
# 1691#4227
# 1691#8347
# 876#4227
# 87#4227
# 876#4227
# 876#8243
# 1064#3146
# 132#3146
# 1064#3146
# 1064#603
# 1074#2523
# 1074#14936
# 785#21197
# 1287#21197
# 785#21197
# 576#21197
# 785#21197
# 785#4818
# 785#21197
# 785#17244
# 785#12734
# 1762#12734
# 785#12734
# 785#4818
# 785#12734
# 785#17244
# 1139#9086
# 101#9086
# 1139#9086
# 329#9086
# 1139#9086
# 338#9086
# 261#3778
# 2108#3778
# 261#3778
# 261#9170
# 1842#2327
# 1842#9547
# 819#980
# 819#15143
# 66#7157
# 2192#7157
# 66#7157
# 66#10313
# 1479#1767
# 2523#1767
# 1479#1767
# 1479#17554
# 1529#812
# 1529#6114
# 637#9152
# 637#6289
# 2210#17163
# 1511#17163
# 2210#17163
# 564#17163
# 2210#17163
# 2210#9068
# 873#15269
# 873#4194
# 1933#9017
# 108#9017
# 1933#9017
# 1958#9017
# 1933#9017
# 1015#9017
# 1933#9017
# 1933#9241
# 1933#9096
# 1933#9241
# 87#7611
# 87#4227
# 87#7611
# 87#9190
# 87#11618
# 87#4227
# 87#11618
# 87#9190
# 1300#15463
# 1300#6920
# 1300#15463
# 1300#767
# 1300#14224
# 1300#6920
# 1300#14224
# 1300#767
# 149#18937
# 149#15776
# 149#18937
# 149#18429
# 149#18937
# 149#4046
# 149#16351
# 149#15776
# 149#16351
# 149#18429
# 149#16351
# 149#4046
# 149#16399
# 149#15776
# 149#16399
# 149#18429
# 149#16399
# 149#4046
# 1981#1503
# 2133#1503
# 1981#1503
# 1981#7376
# 1981#4279
# 1981#7376
# 1585#11476
# 1585#20698
# 1993#1275
# 1993#6496
# 546#7625
# 405#7625
# 546#7625
# 546#13190
# 1989#9475
# 1195#9475
# 1989#9475
# 1989#5332
# 1989#9475
# 1989#15145
# 1989#2477
# 1989#5332
# 1989#2477
# 1989#15145
# 1875#14195
# 1292#14195
# 1875#14195
# 1596#14195
# 1875#14195
# 1875#20009
# 35#3068
# 35#20007
# 2057#3068
# 2057#3314
# 1462#3781
# 192#3781
# 1462#3781
# 1462#124
# 1066#10601
# 1066#2487
# 1008#11117
# 1378#11117
# 1008#11117
# 2166#11117
# 1008#11117
# 1008#5345
# 1008#18143
# 1636#18143
# 1008#18143
# 1008#5345
# 1398#20806
# 2194#20806
# 1398#20806
# 1398#18835
# 416#20386
# 131#20386
# 416#20386
# 799#20386
# 416#20386
# 667#20386
# 416#20386
# 416#639
# 416#17244
# 785#17244
# 416#17244
# 416#639
# 2541#5176
# 2541#20107
# 174#1250
# 174#12345
# 1257#20412
# 1257#9875
# 390#10544
# 1785#10544
# 390#10544
# 390#16296
# 904#16990
# 904#2899
# 469#20646
# 469#21618
# 1654#1650
# 1654#14278
# 2101#20732
# 2101#15416
# 2520#2669
# 2520#19541
# 414#1678
# 1814#1678
# 414#1678
# 414#12839
# 449#13174
# 449#4108
# 449#13174
# 449#9836
# 109#21710
# 109#16245
# 2245#595
# 1146#595
# 2245#595
# 2245#13121
# 524#7631
# 1166#7631
# 524#7631
# 524#20184
# 524#7631
# 524#20393
# 524#3627
# 524#20184
# 524#3627
# 524#20393
# 4#4379
# 1509#4379
# 4#4379
# 4#4818
# 738#6760
# 1126#6760
# 738#6760
# 738#8497
# 1615#11351
# 1615#12628
# 499#5578
# 499#7227
# 2022#17375
# 2022#19356
# 2022#17375
# 2022#10644
# 2022#17452
# 2022#19356
# 2022#17452
# 2022#10644
# 1012#13414
# 2409#13414
# 1012#13414
# 1012#10205
# 932#6452
# 932#18153
# 1592#3206
# 258#3206
# 1592#3206
# 1592#20940
# 689#4784
# 689#16007
# 1249#16299
# 1249#1464
# 2335#10109
# 2335#12960
# 2408#12312
# 2408#11663
# 1561#19670
# 1561#20893
# 811#11429
# 811#3026
# 811#1481
# 811#3026
# 993#19593
# 993#21486
# 476#12747
# 476#3794
# 476#12747
# 476#4785
# 476#20393
# 524#20393
# 476#20393
# 1969#20393
# 476#20393
# 476#3794
# 476#20393
# 476#4785
# 711#2946
# 711#3751
# 604#21732
# 604#6694
# 636#7146
# 1889#7146
# 636#7146
# 636#5486
# 1025#12675
# 304#12675
# 1025#12675
# 1025#9964
# 1178#20812
# 1178#11213
# 376#5042
# 849#5042
# 376#5042
# 2040#5042
# 376#5042
# 376#10286
# 376#5042
# 376#2875
# 2041#9551
# 20#9551
# 2041#9551
# 2041#18949
# 2361#17906
# 2361#12639
# 1403#20184
# 524#20184
# 1403#20184
# 1403#19139
# 2218#18301
# 2218#9718
# 505#15432
# 1149#15432
# 505#15432
# 505#3145
# 2340#2237
# 927#2237
# 2340#2237
# 2340#17788
# 2055#7602
# 2055#5343
# 2055#7602
# 2055#3093
# 557#6722
# 2318#6722
# 557#6722
# 557#9517
# 2112#3378
# 1264#3378
# 2112#3378
# 2112#14944
# 389#1451
# 389#21372
# 323#9991
# 1549#9991
# 323#9991
# 323#20078
# 377#9390
# 377#17918
# 1830#19354
# 1830#11966
# 131#9891
# 131#20386
# 1592#17448
# 1592#20940
# 673#2945
# 673#19113
# 2180#18388
# 2180#20007
# 2318#15826
# 1869#15826
# 2318#15826
# 2318#6722
# 987#6670
# 987#8589
# 2094#11401
# 2409#11401
# 2094#11401
# 2094#10202
# 2094#11401
# 2094#6761
# 2094#16312
# 2094#10202
# 2094#16312
# 2094#6761
# 1906#7801
# 1906#6195
# 2019#11228
# 2019#6046
# 94#8351
# 94#2084
# 600#557
# 2344#557
# 600#557
# 600#10441
# 501#12545
# 501#17462
# 501#12545
# 501#17720
# 2166#21077
# 2166#11117
# 2166#21077
# 2166#12174
# 2166#18478
# 2166#11117
# 2166#18478
# 2166#12174
# 220#8697
# 220#1903
# 430#3274
# 430#17259
# 2441#6644
# 1658#6644
# 2441#6644
# 2441#1024
# 2325#20694
# 2134#20694
# 2325#20694
# 2325#19892
# 108#12091
# 108#9017
# 1618#2749
# 1618#880
# 1618#2749
# 1618#10543
# 212#401
# 212#7339
# 20#13058
# 20#9551
# 20#13058
# 20#17840
# 20#17430
# 20#9551
# 20#17430
# 20#17840
# 1195#14917
# 1195#9475
# 529#77
# 529#2721
# 529#77
# 529#11285
# 529#21348
# 2038#21348
# 529#21348
# 1517#21348
# 529#21348
# 529#2721
# 529#21348
# 529#11285
# 2341#3759
# 2341#21507
# 1511#19043
# 1511#17163
# 2200#20396
# 2200#9482
# 2200#20396
# 2200#11137
# 2200#18139
# 2200#9482
# 2200#18139
# 2200#11137
# 1536#19000
# 1536#16061
# 2168#14881
# 2168#12662
# 1476#8651
# 2330#8651
# 1476#8651
# 1476#2721
# 1476#8651
# 1476#21913
# 1476#12655
# 1476#2721
# 1476#12655
# 1476#21913
# 470#2721
# 529#2721
# 470#2721
# 1476#2721
# 470#2721
# 470#18198
# 152#692
# 1985#692
# 152#692
# 152#5286
# 2328#8545
# 670#8545
# 2328#8545
# 899#8545
# 2328#8545
# 663#8545
# 2328#8545
# 2328#1418
# 721#13399
# 721#10508
# 1194#5593
# 1194#2299
# 1194#4494
# 81#4494
# 1194#4494
# 1194#2299
# 896#12464
# 896#17830
# 1293#18603
# 1188#18603
# 1293#18603
# 1293#5209
# 1386#17537
# 1386#16385
# 1682#13298
# 1682#14876
# 1716#20592
# 2202#20592
# 1716#20592
# 1716#19597
# 2095#15248
# 2095#3010
# 1550#18949
# 786#18949
# 1550#18949
# 2041#18949
# 1550#18949
# 1550#4682
# 2343#639
# 416#639
# 2343#639
# 2343#21662
# 223#17535
# 1674#17535
# 223#17535
# 223#11622
# 1553#9157
# 2388#9157
# 1553#9157
# 1969#9157
# 1553#9157
# 1572#9157
# 940#3616
# 940#10725
# 448#13175
# 448#11327
# 179#19150
# 179#10675
# 2316#9549
# 2191#9549
# 2316#9549
# 2316#6120
# 2072#8815
# 2072#569
# 1940#20178
# 1940#4567
# 1152#18331
# 1152#7393
# 624#14736
# 624#6110
# 135#3741
# 1773#3741
# 135#3741
# 135#10680
# 2395#13252
# 2395#22044
# 425#8535
# 1801#8535
# 425#8535
# 425#4682
# 1526#12544
# 1526#20660
# 1739#20133
# 1739#7415
# 2549#19118
# 2549#19557
# 2134#8991
# 2134#18705
# 2134#8991
# 2134#20694
# 2134#10435
# 2134#18705
# 2134#10435
# 2134#20694
# 96#10967
# 837#10967
# 96#10967
# 96#16040
# 945#14178
# 945#10647
# 1032#13439
# 1032#1663
# 849#603
# 1064#603
# 849#603
# 849#5042
# 2001#14203
# 2001#2148
# 1642#11045
# 127#11045
# 1642#11045
# 1642#17422
# 1166#3696
# 1166#7631
# 1777#13180
# 1777#3447
# 1777#13180
# 1777#2439
# 1777#16438
# 899#16438
# 1777#16438
# 1777#3447
# 1777#16438
# 1777#2439
# 1415#2486
# 1415#19236
# 1415#11940
# 1932#11940
# 1415#11940
# 1415#19236
# 59#21240
# 59#20814
# 1306#2559
# 1306#11663
# 1622#16059
# 1622#11010
# 833#4598
# 833#19476
# 833#4598
# 833#3472
# 833#19557
# 2549#19557
# 833#19557
# 2275#19557
# 833#19557
# 833#19476
# 833#19557
# 833#3472
# 806#14295
# 806#4567
# 1381#20891
# 1381#21499
# 1530#1442
# 1103#1442
# 1530#1442
# 1530#10951
# 1143#14278
# 1654#14278
# 1143#14278
# 348#14278
# 1143#14278
# 1143#14366
# 1006#11658
# 1006#345
# 1208#6899
# 1208#14762
# 2469#10814
# 2469#17619
# 1167#3904
# 1167#12363
# 2185#11690
# 1081#11690
# 2185#11690
# 549#11690
# 2185#11690
# 2185#15122
# 1969#10525
# 1969#20393
# 1969#10525
# 1969#9157
# 1969#21512
# 1969#20393
# 1969#21512
# 1969#9157
# 335#10662
# 335#14644
# 1395#19581
# 1395#12408
# 1685#17949
# 559#17949
# 1685#17949
# 1685#20213
# 1401#14944
# 2112#14944
# 1401#14944
# 1401#15110
# 2265#19008
# 2265#13319
# 2029#12892
# 719#12892
# 2463#14118
# 2463#19348
# 2484#11842
# 2125#11842
# 2484#11842
# 2484#2780
# 1540#4757
# 1540#14360
# 998#4380
# 232#4380
# 998#4380
# 998#15143
# 1201#19355
# 1201#18989
# 1513#20845
# 2246#20845
# 1513#20845
# 1513#6041
# 2417#5900
# 2417#17911
# 1218#5250
# 726#5250
# 1218#5250
# 1218#12432
# 1535#1091
# 1535#3695
# 512#1393
# 512#20575
# 2365#16367
# 2365#6877
# 802#13030
# 802#10264
# 1661#11173
# 1346#11173
# 1661#11173
# 1661#11663
# 1896#7661
# 971#7661
# 1896#7661
# 1896#3258
# 1425#8193
# 1425#15278
# 590#15496
# 590#195
# 2255#346
# 706#346
# 2255#346
# 2255#5993
# 1977#12094
# 1977#1431
# 127#1556
# 127#11045
# 1210#14110
# 1867#14110
# 1210#14110
# 1210#9875
# 1210#14110
# 1210#18635
# 1122#14110
# 1867#14110
# 1122#14110
# 1122#5332
# 1210#9718
# 2218#9718
# 1210#9718
# 1210#9875
# 1210#9718
# 1210#18635
# 586#14868
# 586#14936
# 329#14370
# 329#9086
# 601#4692
# 1505#4692
# 601#4692
# 601#1108
# 601#4692
# 601#13250
# 601#12882
# 168#12882
# 601#12882
# 601#1108
# 601#12882
# 601#13250
# 2388#20822
# 2388#9157
# 1884#19124
# 2155#19124
# 1191#10707
# 1191#19360
# 936#14801
# 936#6138
# 616#17520
# 616#1024
# 2540#10706
# 2540#2551
# 1616#12974
# 1616#2280
# 1574#5416
# 34#5416
# 1574#5416
# 1574#1464
# 2482#6886
# 2482#17808
# 1727#18464
# 1727#7448
# 456#19348
# 2463#19348
# 456#19348
# 456#2699
# 1418#7249
# 1418#9809
# 1418#7249
# 1418#12327
# 447#5775
# 447#18198
# 1281#17950
# 1908#17950
# 1281#17950
# 2005#17950
# 1281#17950
# 1281#5713
# 1281#17950
# 1281#10333
# 1281#7638
# 1281#5713
# 1281#7638
# 1281#10333
# 1624#6593
# 1999#6593
# 942#2806
# 942#9875
# 772#5518
# 545#5518
# 772#5518
# 772#17887
# 352#10049
# 352#1435
# 718#20107
# 2541#20107
# 718#20107
# 718#11920
# 2017#12007
# 226#12007
# 2017#12007
# 2017#18835
# 2528#13283
# 2528#8392
# 1965#14804
# 1965#14865
# 308#10210
# 308#10883
# 308#10210
# 308#17085
# 79#12348
# 79#7315
# 1958#17571
# 1958#9017
# 1156#14874
# 1156#14762
# 1264#22052
# 1264#3378
# 240#10618
# 240#2140
# 2220#246
# 2220#4785
# 1572#6999
# 1998#6999
# 1572#6999
# 1458#6999
# 1572#6999
# 1572#9157
# 399#16515
# 399#4440
# 1164#6863
# 1164#8357
# 2147#6471
# 2147#15368
# 2397#18102
# 2184#18102
# 2397#18102
# 2397#1005
# 2397#18102
# 2397#16061
# 1440#19655
# 26#19655
# 1440#19655
# 1440#19643
# 1440#19655
# 1440#14467
# 899#15336
# 899#3669
# 899#15336
# 899#16438
# 899#15336
# 899#8545
# 899#7384
# 899#3669
# 899#7384
# 899#16438
# 899#7384
# 899#8545
# 899#11344
# 899#3669
# 899#11344
# 899#16438
# 899#11344
# 899#8545
# 357#21592
# 2030#21592
# 357#21592
# 2231#21592
# 357#21592
# 357#7415
# 1361#995
# 2502#995
# 1361#995
# 1361#10682
# 287#18627
# 1559#18627
# 287#18627
# 1704#18627
# 287#18627
# 287#7287
# 2539#2280
# 1616#2280
# 2539#2280
# 2539#17893
# 1150#9482
# 2200#9482
# 1150#9482
# 1150#11327
# 1551#11327
# 1150#11327
# 1551#11327
# 298#11327
# 1551#11327
# 448#11327
# 1551#11327
# 1559#11327
# 2460#7487
# 2460#1684
# 589#20109
# 562#20109
# 589#20109
# 589#3924
# 1109#10673
# 1109#12447
# 2165#3695
# 1535#3695
# 2165#3695
# 706#3695
# 2165#3695
# 2165#5868
# 223#1355
# 223#11622
# 1793#8495
# 1793#12648
# 2107#1254
# 2107#11642
# 1611#10451
# 1611#10855
# 1036#21948
# 1036#17840
# 232#10437
# 232#4380
# 1610#2510
# 1610#6101
# 659#21943
# 659#8546
# 663#17259
# 430#17259
# 663#17259
# 663#8545
# 1312#14761
# 1312#2534
# 1838#13678
# 1838#17495
# 1219#5268
# 1219#3017
# 1988#10906
# 2194#10906
# 1988#10906
# 1988#19454
# 2523#3325
# 2523#1767
# 1120#3472
# 833#3472
# 1120#3472
# 1120#21737
# 781#14279
# 781#17975
# 1108#12701
# 1108#11081
# 2120#20315
# 2120#19451
# 2191#21662
# 2343#21662
# 2191#21662
# 2191#7478
# 2191#21662
# 2191#9549
# 2191#2311
# 2191#7478
# 2191#2311
# 2191#9549
# 2267#13319
# 2265#13319
# 2267#13319
# 2267#8744
# 562#18153
# 932#18153
# 562#18153
# 562#20109
# 508#11954
# 508#14756
# 2126#16073
# 2126#19139
# 1369#12443
# 1369#8871
# 2125#11565
# 2125#11842
# 706#12896
# 706#3695
# 706#12896
# 706#346
# 706#16537
# 706#3695
# 706#16537
# 706#346
# 743#8236
# 743#17952
# 2085#8988
# 2085#12493
# 2275#357
# 2275#19557
# 1559#4509
# 1559#11327
# 1559#4509
# 1559#18627
# 1559#12853
# 2156#12853
# 1559#12853
# 1559#11327
# 1559#12853
# 1559#18627
# 2214#21799
# 2214#20144
# 1146#4788
# 121#4788
# 1146#4788
# 1146#5889
# 1146#4788
# 1146#595
# 1146#2868
# 1262#2868
# 1146#2868
# 417#2868
# 1146#2868
# 1146#5889
# 1146#2868
# 1146#595
# 1883#10855
# 1611#10855
# 1883#10855
# 1030#10855
# 1883#10855
# 1883#15684
# 2077#18298
# 2077#15145
# 1316#15123
# 1937#15123
# 1316#15123
# 1316#1306
# 1316#21113
# 1316#1306
# 1700#17104
# 1700#9068
# 484#9131
# 484#10801
# 2020#16544
# 2020#8834
# 432#18465
# 432#2560
# 670#12491
# 1878#12491
# 670#12491
# 670#8545
# 195#6877
# 2365#6877
# 195#6877
# 195#21285
# 195#6877
# 195#15781
# 195#20940
# 1592#20940
# 195#20940
# 195#21285
# 195#20940
# 195#15781
# 2511#11626
# 2511#17145
# 259#10647
# 1968#10647
# 259#10647
# 1234#10647
# 259#10647
# 945#10647
# 259#10647
# 695#10647
# 259#10647
# 259#4715
# 2018#16794
# 346#16794
# 2018#16794
# 751#16794
# 2018#16794
# 2018#3669
# 316#7706
# 316#3248
# 471#10875
# 471#1226
# 429#6991
# 429#21841
# 2428#1157
# 2428#8871
# 1011#15004
# 1011#6720
# 1094#16870
# 1094#18835
# 1094#16870
# 1094#16087
# 1094#5463
# 1094#18835
# 1094#5463
# 1094#16087
# 1549#9246
# 1549#9991
# 1346#20146
# 1346#8334
# 1346#20146
# 1346#11173
# 1346#14258
# 1346#8334
# 1346#14258
# 1346#11173
# 1500#4638
# 2419#4638
# 1500#4638
# 1500#16353
# 1015#7029
# 1015#9017
# 694#105
# 694#677
# 2462#13244
# 2462#1628
# 1010#781
# 1010#13621
# 2014#9227
# 2014#18495
# 2155#11212
# 2155#19124
# 1772#236
# 1772#6829
# 700#3857
# 700#11720
# 1705#16232
# 1705#6276
# 531#6616
# 531#18197
# 539#10462
# 750#10462
# 539#10462
# 539#17195
# 2192#16174
# 2192#7157
# 1317#4507
# 1317#12292
# 1486#1376
# 1486#18989
# 1509#19515
# 1509#4379
# 1245#10289
# 1245#8408
# 2117#14496
# 2117#11193
# 1230#5843
# 1230#7563
# 27#538
# 27#10675
# 1719#12857
# 1719#20341
# 1719#12857
# 1719#2315
# 1719#8846
# 1719#20341
# 1719#8846
# 1719#2315
# 515#14882
# 515#20348
# 2260#14835
# 2260#15278
# 1863#15435
# 86#15435
# 1863#15435
# 1863#7415
# 1636#20244
# 1636#18143
# 829#10888
# 829#11485
# 304#19300
# 304#12675
# 2410#11715
# 2410#1851
# 1356#560
# 1356#19236
# 1759#13846
# 1759#21804
# 1759#13846
# 1759#20420
# 1759#9790
# 1759#21804
# 1759#9790
# 1759#20420
# 2423#8664
# 2423#767
# 2246#3567
# 2246#20845
# 1507#16667
# 1507#17351
# 81#6527
# 938#6527
# 81#6527
# 81#4494
# 2030#14036
# 2030#21592
# 1186#11040
# 1186#15122
# 57#9165
# 57#14169
# 1399#4587
# 1399#11393
# 30#6032
# 2493#6032
# 30#6032
# 30#259
# 1433#6231
# 1433#21975
# 1419#14716
# 1419#10397
# 664#7136
# 664#5196
# 1514#1593
# 1263#1593
# 1514#1593
# 1514#19856
# 164#124
# 2483#124
# 164#124
# 1462#124
# 164#124
# 164#10470
# 138#21121
# 138#4745
# 2543#6691
# 2543#8560
# 2502#4363
# 2502#995
# 1252#2074
# 1252#429
# 661#10274
# 661#14558
# 2140#102
# 2350#102
# 2140#102
# 2140#11396
# 2521#15684
# 2053#15684
# 2521#15684
# 1234#15684
# 2521#15684
# 1883#15684
# 2521#15684
# 2521#14789
# 121#14796
# 121#4788
# 2439#2862
# 2439#17975
# 2256#14016
# 2256#9547
# 1325#913
# 2079#913
# 1325#913
# 1325#11121
# 1596#13391
# 1596#14195
# 1371#5173
# 1371#7315
# 739#18198
# 470#18198
# 739#18198
# 447#18198
# 739#18198
# 739#18705
# 481#377
# 481#7240
# 2350#18167
# 2350#102
# 129#2702
# 129#20604
# 1954#11439
# 1247#11439
# 1954#11439
# 1905#11439
# 1954#11439
# 1954#18740
# 1593#16659
# 1593#9875
# 185#2960
# 185#16333
# 568#12174
# 2166#12174
# 568#12174
# 568#14467
# 1644#2780
# 2484#2780
# 1644#2780
# 1644#14196
# 1392#2977
# 1392#13922
# 872#20289
# 872#11895
# 545#13665
# 519#13665
# 545#13665
# 545#5518
# 693#18705
# 2134#18705
# 693#18705
# 739#18705
# 693#18705
# 693#3580
# 646#6761
# 2094#6761
# 646#6761
# 646#14870
# 937#14005
# 937#19597
# 2137#4706
# 2137#9561
# 477#2718
# 477#1173
# 1905#15685
# 1905#11439
# 538#791
# 538#262
# 89#3270
# 89#4577
# 89#3270
# 89#12413
# 89#18981
# 2197#18981
# 89#18981
# 89#4577
# 89#18981
# 89#12413
# 1814#3254
# 1814#1678
# 1814#3254
# 1814#195
# 1814#1608
# 1814#1678
# 1814#1608
# 1814#195
# 903#6662
# 1855#6662
# 903#6662
# 903#6915
# 903#6662
# 903#13797
# 903#18251
# 903#6915
# 903#18251
# 903#13797
# 2193#3145
# 505#3145
# 2193#3145
# 2193#5721
# 997#2751
# 997#14902
# 267#2950
# 267#17771
# 1627#13620
# 1627#9731
# 2062#353
# 2489#353
# 2062#353
# 2062#15666
# 1030#16792
# 1030#10855
# 976#13423
# 976#19289
# 2232#17840
# 20#17840
# 2232#17840
# 1036#17840
# 2232#17840
# 2232#15455
# 1856#12475
# 1856#14712
# 1341#8497
# 738#8497
# 1341#8497
# 1341#9676
# 519#2139
# 519#13665
# 1366#18373
# 1366#21975
# 2231#12950
# 2231#21592
# 1335#8619
# 1113#8619
# 1335#8619
# 1335#14079
# 2419#7680
# 2419#4638
# 1974#3156
# 1974#6809
# 1767#5889
# 1146#5889
# 1767#5889
# 1767#7040
# 1096#2703
# 1096#12838
# 2217#17495
# 1838#17495
# 2217#17495
# 2217#8331
# 55#6573
# 2379#6573
# 55#6573
# 55#8634
# 2040#7444
# 2040#5042
# 2027#3204
# 2027#6580
# 2027#3204
# 2027#5627
# 8#1304
# 8#20660
# 564#18916
# 564#17163
# 2508#5039
# 2508#5813
# 1363#17389
# 1363#11622
# 618#19541
# 2520#19541
# 618#19541
# 618#16163
# 1778#3751
# 711#3751
# 1778#3751
# 1778#19120
# 2007#13922
# 1392#13922
# 2007#13922
# 2007#15451
# 1944#15781
# 195#15781
# 1944#15781
# 1944#7332
# 1944#15781
# 1944#5209
# 1348#12432
# 1218#12432
# 1348#12432
# 1348#21064
# 2102#15844
# 2102#7332
# 2108#8359
# 2108#3778
# 971#6931
# 971#7661
# 2000#20190
# 2000#13158
# 2000#20190
# 2000#19937
# 2327#1682
# 2327#11146
# 2164#8470
# 2164#16005
# 1565#6915
# 903#6915
# 1565#6915
# 1565#14976
# 653#6709
# 653#2465
# 812#454
# 812#10377
# 137#2577
# 137#21311
# 530#17880
# 530#2058
# 1442#15285
# 1442#4064
# 708#11830
# 708#8740
# 1237#7616
# 1237#20232
# 1424#9728
# 1424#1936
# 1002#6639
# 1002#6217
# 1302#6495
# 1302#8674
# 387#4059
# 387#8523
# 1397#2439
# 1777#2439
# 1397#2439
# 1397#6101
# 1578#13541
# 1578#16442
# 2230#14756
# 508#14756
# 2230#14756
# 2230#4715
# 2344#4785
# 476#4785
# 2344#4785
# 2220#4785
# 2344#4785
# 2344#557
# 2150#4785
# 476#4785
# 2150#4785
# 2220#4785
# 2150#4785
# 2150#21075
# 2489#5636
# 2489#353
# 1734#21813
# 1734#15059
# 1939#19139
# 1403#19139
# 1939#19139
# 2126#19139
# 1939#19139
# 1939#6091
# 1998#12452
# 1998#6999
# 782#17484
# 2436#17484
# 782#17484
# 782#11146
# 2516#4425
# 2516#16402
# 667#12515
# 667#20386
# 2306#10516
# 2306#10015
# 556#19010
# 556#18815
# 1785#11404
# 1785#10544
# 1619#6365
# 1619#6914
# 1847#15548
# 1847#17422
# 1707#17027
# 1105#17027
# 1707#17027
# 1707#17264
# 65#8392
# 2528#8392
# 65#8392
# 65#5621
# 228#2203
# 1427#2203
# 228#2203
# 228#8724
# 226#12628
# 1615#12628
# 226#12628
# 226#12007
# 2472#19284
# 2472#572
# 379#21691
# 379#21372
# 1698#16579
# 1698#15776
# 938#19776
# 938#6527
# 2160#17900
# 2160#9333
# 1658#16333
# 185#16333
# 1658#16333
# 1658#6644
# 2372#10924
# 2372#7185
# 396#100
# 1695#100
# 396#100
# 396#12885
# 1370#14865
# 1965#14865
# 1370#14865
# 1370#17544
# 750#15431
# 750#10462
# 865#11895
# 872#11895
# 865#11895
# 865#7132
# 1876#9387
# 1876#20456
# 247#19032
# 247#9970
# 1126#8268
# 1126#6760
# 1985#1121
# 1985#692
# 1211#1325
# 1211#9547
# 909#13024
# 909#11966
# 2369#15352
# 265#15352
# 2369#15352
# 2369#11885
# 854#6748
# 854#3101
# 1638#1271
# 1638#3580
# 1078#11885
# 2369#11885
# 1078#11885
# 1078#2597
# 1937#11296
# 1937#15123
# 70#14642
# 70#10440
# 1225#8071
# 1225#17924
# 1105#1398
# 1105#17027
# 1517#889
# 1517#21348
# 2048#8525
# 2048#2400
# 542#9190
# 87#9190
# 542#9190
# 542#15653
# 1339#17544
# 1370#17544
# 1339#17544
# 1339#3669
# 2379#11831
# 2379#6573
# 1867#14360
# 1540#14360
# 1867#14360
# 1867#14110
# 2031#13168
# 2031#13744
# 1580#11461
# 1580#19368
# 187#1929
# 1278#1929
# 187#1929
# 187#17531
# 2005#19521
# 2005#17950
# 540#11543
# 540#8744
# 1733#5721
# 2193#5721
# 1733#5721
# 1733#13512
# 206#10518
# 206#15145
# 206#10518
# 206#20878
# 2477#6956
# 2477#17975
# 2237#1663
# 1032#1663
# 2237#1663
# 2237#10374
# 2124#1795
# 2124#18495
# 67#3669
# 899#3669
# 67#3669
# 2018#3669
# 67#3669
# 1339#3669
# 67#3669
# 67#1673
# 1190#2760
# 1190#1681
# 277#15427
# 277#17898
# 2330#14074
# 2330#8651
# 724#9676
# 2081#9676
# 724#9676
# 1341#9676
# 724#9676
# 724#10725
# 789#14902
# 997#14902
# 789#14902
# 789#16751
# 1952#20444
# 1952#13760
# 640#7372
# 640#11966
# 361#11567
# 361#19396
# 716#7851
# 716#21841
# 576#5076
# 576#21197
# 202#6829
# 625#6829
# 202#6829
# 1772#6829
# 202#6829
# 202#17830
# 34#11684
# 34#5416
# 1449#7903
# 1449#3025
# 348#14459
# 348#14278
# 2148#2888
# 2148#12779
# 2329#16353
# 1500#16353
# 2329#16353
# 2329#6114
# 1704#17702
# 1704#18627
# 951#15943
# 951#21331
# 1878#2928
# 1878#12491
# 1822#10712
# 1822#18197
# 1864#21326
# 1864#11255
# 2157#14546
# 2157#6601
# 871#14931
# 1973#14931
# 871#14931
# 871#21372
# 1427#10693
# 1427#2203
# 1653#14385
# 1653#16642
# 751#10531
# 751#16794
# 1084#20645
# 1084#3247
# 1461#14499
# 1461#15451
# 631#12818
# 631#15576
# 559#5884
# 559#17949
# 497#4497
# 311#4497
# 497#4497
# 497#20564
# 417#19476
# 833#19476
# 417#19476
# 417#2868
# 2079#3895
# 2079#913
# 320#21484
# 320#6717
# 1458#8347
# 1691#8347
# 1458#8347
# 1458#6999
# 1801#256
# 1801#8535
# 2497#12025
# 2497#12576
# 2294#6549
# 2294#21945
# 837#8740
# 2550#8740
# 837#8740
# 708#8740
# 837#8740
# 837#10967
# 560#21311
# 137#21311
# 560#21311
# 560#19485
# 695#20007
# 35#20007
# 695#20007
# 2180#20007
# 695#20007
# 695#10647
# 2486#8096
# 2486#20703
# 2436#20420
# 1759#20420
# 2436#20420
# 2436#17484
# 1263#12735
# 1263#1593
# 1855#10031
# 1855#6662
# 338#6116
# 338#9086
# 311#4721
# 311#4497

# %%
augmented_train[augmented_train.id=='2354#167']
# Out:
#    label ltable_brand ltable_modelno  \
# 0      1         Sony       DPW30R2H
#
#                                ltable_title  ltable_price  \
# 0  Sony DPW30R2H 1.4GB Camcorder 8cm DVD RW          8.88
#
#          ltable_dimensions                                    ltable_imageurl  \
# 0  4.0 x 3.6 x 0.25 inches  http://i.walmartimages.com/i/p/00/02/72/42/66/...
#
#    ltable_shipweight rtable_brand rtable_modelno  \
# 0               0.18         Sony       DPW30R2H
#
#                                        rtable_title  rtable_price  \
# 0  Sony Dpw30R2H 1.4 Gb Camcorder 8Cm Dvd Rw Single          3.49
#
#         rtable_dimensions                                    rtable_imageurl  \
# 0  3.9 x 3.5 x 0.3 inches  http://ecx.images-amazon.com/images/I/51SDD1DW...
#
#   rtable_shipweight          id
# 0          1 pounds  2354#13477

# %%
test_fodors = pd.read_csv('datasets/fodors_zagats/augmented_test.csv')
fodors = pd.read_csv('datasets/fodors_zagats/fodors.csv',dtype=str)
zagats = pd.read_csv('datasets/fodors_zagats/zagats.csv',dtype=str)
triangles_fodors = getMixedTriangles(test_fodors,[fodors,zagats])
testTriangles(test_fodors,triangles_fodors)

# %% [markdown]
# ## Compare black and white model

# %%
itunes_model = dm.MatchingModel(attr_summarizer='hybrid')
itunes_model.load_state('models/itunes_amazon_hybrid.pth')
itunes = pd.read_csv('datasets/itunes_amazon/itunes.csv')

# %%
itunes_model = itunes_model.to('cuda')
explainer_itunes = Explainer(itunes_model,[attr for attr in itunes.columns if attr not in ['id']])

# %%
negranking,negri,testneg = explainer_itunes.getRankingsWhiteBox('datasets/itunes_amazon/','augmented_test',
                                                       0,'cosine')
# Out:
# Computing vectors in the classifier space
#   0%|          | 0/90 [00:00<?, ?it/s]
# 112
# 4
# 100%|██████████| 90/90 [00:44<00:00,  2.01it/s]

# %%
negri.drop(['sample_id'],axis=1).mean().plot.bar()

# %%
posranking,posri,testpos = explainer_itunes.getRankingsWhiteBox('datasets/itunes_amazon/','augmented_test',
                                                       1,'cosine')
# Out:
# Computing vectors in the classifier space
#   0%|          | 0/22 [00:00<?, ?it/s]
# 112
# 4
# 100%|██████████| 22/22 [00:08<00:00,  2.58it/s]

# %%
posri.drop(['sample_id'],axis=1).mean().plot.bar()

# %%
walmart_model = dm.MatchingModel(attr_summarizer='hybrid')
walmart_model.load_state('models/walmart_amazon_hybrid.pth')
walmart_model = walmart_model.to('cuda')

# %%
walmart = pd.read_csv('datasets/walmart_amazon/walmart.csv')
walmart_explainer = Explainer(walmart_model,[attr for attr in walmart.columns if attr not in ['id']])

# %%
negranking,negri,testneg = walmart_explainer.getRankingsWhiteBox('datasets/walmart_amazon/','augmented_test',
                                                       0,'cosine')
# Out:
# Computing vectors in the classifier space
#   0%|          | 0/619 [00:00<?, ?it/s]
# 838
# 27
# 100%|██████████| 619/619 [05:55<00:00,  1.74it/s]

# %%
negri.drop(['sample_id'],axis=1).mean().plot.bar(color='red')

# %%
posranking,posri,testpos = walmart_explainer.getRankingsWhiteBox('datasets/walmart_amazon/','augmented_test',
                                                       1,'cosine')
# Out:
# Computing vectors in the classifier space
#   0%|          | 0/219 [00:00<?, ?it/s]
# 838
# 27
# 100%|██████████| 219/219 [02:05<00:00,  1.74it/s]

# %%
posri.drop(['sample_id'],axis=1).mean().plot.bar(color='green')

# %%
beer_model = dm.MatchingModel(attr_summarizer='hybrid')
beer_model.load_state('models/beeradvo_ratebeer_hybrid.pth')
beeradvo = pd.read_csv('datasets/beeradvo_ratebeer/Beeradvo.csv')
beer_model = beer_model.to('cuda')

# %%
beer_explainer = Explainer(beer_model,[attr for attr in beeradvo.columns if attr not in ['id']])

# %%
negranking,negri,testneg = beer_explainer.getRankingsWhiteBox('datasets/beeradvo_ratebeer/','augmented_test',
                                                       0,'cosine')
# Out:
# Computing vectors in the classifier space
#   0%|          | 0/55 [00:00<?, ?it/s]
# 74
# 3
# 100%|██████████| 55/55 [00:09<00:00,  5.51it/s]

# %%
posrank,posri,testpos = beer_explainer.getRankingsWhiteBox('datasets/beeradvo_ratebeer/','augmented_test',
                                                          1,'cosine')
# Out:
# Computing vectors in the classifier space
#   0%|          | 0/19 [00:00<?, ?it/s]
# 74
# 3
# 100%|██████████| 19/19 [00:02<00:00,  6.78it/s]

# %%
negri.drop(['sample_id'],axis=1).mean().plot.bar(color='red')

# %%
posri.drop(['sample_id'],axis=1).mean().plot.bar(color='green')

# %%
dblpacm_model = dm.MatchingModel(attr_summarizer='hybrid')
dblpacm_model.load_state('models/dblp_acm_hybrid.pth')
dblpacm_model = dblpacm_model.to('cuda')

# %%
dblp = pd.read_csv('datasets/DBLP-ACM/DBLP2.csv')
dblpacm_explainer = Explainer(dblpacm_model,[attr for attr in dblp.columns if attr not in ['id']])

# %%
negranking,negri,testneg = dblpacm_explainer.getRankingsWhiteBox('datasets/DBLP-ACM/','augmented_test',
                                                       0,'cosine')
# Out:
# Computing vectors in the classifier space
#   0%|          | 0/760 [00:00<?, ?it/s]
# 1186
# 38
# 100%|██████████| 760/760 [03:52<00:00,  3.27it/s]

# %%
negri.drop(['sample_id'],axis=1).mean().plot.bar(color='red',ylim=(0,1))

# %%
posranking,posri,testpos = dblpacm_explainer.getRankingsWhiteBox('datasets/DBLP-ACM/','augmented_test',
                                                       1,'cosine')
# Out:
# Computing vectors in the classifier space
#   0%|          | 0/426 [00:00<?, ?it/s]
# 1186
# 38
# 100%|██████████| 426/426 [01:24<00:00,  5.05it/s]

# %%
posri.drop(['sample_id'],axis=1).mean().plot.bar(color='green',ylim=(0,1))

# %% [markdown]
# ## Test groups of attributes

# %%
from explanation.deepmatcher_utils import wrapDm

# %%
predict_fn_deepmatcher = lambda data,model,ignore: wrapDm(data,model,ignore_columns=ignore)

# %%
#to filter most important set of attributes
def filterRankings(rankings,threshold):
    for attrset,importance in rankings:

# %% [markdown]
# ### Beer

# %%
augmented_test = pd.read_csv('datasets/beeradvo_ratebeer/augmented_test.csv')
beeradvo = pd.read_csv('datasets/beeradvo_ratebeer/Beeradvo.csv',dtype=str)
ratebeer = pd.read_csv('datasets/beeradvo_ratebeer/Ratebeer.csv',dtype=str)

# %%
beer_deepmatcher = dm.MatchingModel(attr_summarizer='rnn')
beer_deepmatcher.load_state('models/beeradvo_ratebeer_rnn.pth')

# %%
negrank_beer,_ = explainSamples(augmented_test,[beeradvo,ratebeer],beer_deepmatcher,predict_fn_deepmatcher,
                                 0,maxLenAttributeSet=3)
# Out:
# 100%|██████████| 30/30 [00:03<00:00,  8.94it/s]

# %%
beer_ax = negrank_deeper.plot.barh(color='red',grid=True)

# %%
figure = beer_ax.get_figure()
figure.savefig('negrank_beer.png',dpi=300,bbox_inches='tight')

# %% [markdown]
# ### Walmart-Amazon

# %%
augmented_test = pd.read_csv('datasets/walmart_amazon/augmented_test.csv')
walmart = pd.read_csv('datasets/walmart_amazon/walmart.csv',dtype=str)
amazon = pd.read_csv('datasets/walmart_amazon/amazon.csv',dtype=str)

# %%
walmart_deepmatcher = dm.MatchingModel(attr_summarizer='rnn')
walmart_deepmatcher.load_state('models/walmart_amazon_rnn.pth')

# %%
negrank_deepmatcher,_ = explainSamples(augmented_test,[walmart,amazon],walmart_deepmatcher,
                             predict_fn_deepmatcher,0,maxLenAttributeSet=4)
# Out:
# 100%|██████████| 548/548 [07:41<00:00,  1.19it/s]

# %%
negrank_deepmatcher_filtered = negrank_deepmatcher[negrank_deepmatcher>0.7]
ax_walmart = negrank_deepmatcher_filtered.plot.barh(color='red',grid=True)
fig = ax_walmart.get_figure()
fig.savefig('negrank_walmart.png',dpi=300,bbox_inches='tight')

# %% [markdown]
# ### DBLP-ACM

# %%
augmented_test = pd.read_csv('datasets/DBLP-ACM/augmented_test.csv')
dblp = pd.read_csv('datasets/DBLP-ACM/DBLP2.csv',dtype=str)
acm = pd.read_csv('datasets/DBLP-ACM/ACM.csv',dtype=str)

# %%
dblpacm_deepmatcher = dm.MatchingModel(attr_summarizer='rnn')
dblpacm_deepmatcher.load_state('models/dblp_acm_rnn.pth')

# %%
negrank_dblpacm,_ = explainSamples(augmented_test,[dblp,acm],dblpacm_deepmatcher,predict_fn_deepmatcher,
                                        0,maxLenAttributeSet=3)
# Out:
# 100%|██████████| 629/629 [02:34<00:00,  4.07it/s]

# %%
ax_dblpacm = negrank_dblpacm.plot.barh(color='red',grid=True)
fig = ax_dblpacm.get_figure()
fig.savefig('negrank_dblpacm.png',dpi=300,bbox_inches='tight')

# %% [markdown]
# ### Itunes-Amazon

# %%
DATASET_DIR = 'datasets/itunes_amazon/'
augmented_test = pd.read_csv(DATASET_DIR+'augmented_test.csv')
itunes = pd.read_csv(DATASET_DIR+'itunes.csv',dtype=str)
amazon = pd.read_csv(DATASET_DIR+'amazon.csv',dtype=str)

# %%
itunes_deepmatcher = dm.MatchingModel(attr_summarizer='rnn')
itunes_deepmatcher.load_state('models/itunes_amazon_rnn.pth')

# %%
negrank_itunes,_ = explainSamples(augmented_test,[itunes,amazon],itunes_deepmatcher,
                                         predict_fn_deepmatcher,0,maxLenAttributeSet=4)
# Out:
# 100%|██████████| 76/76 [01:31<00:00,  1.21s/it]

# %%
negrank_itunes_filt = negrank_itunes[negrank_itunes>=0.6]
ax_itunes = negrank_itunes_filt.plot.barh(color='red',grid=True)
fig = ax_itunes.get_figure()
fig.savefig('negrank_itunes_amazon.png',dpi=300,bbox_inches='tight')

# %% [markdown]
# ## Test vanilla gradient

# %%
DATASET_DIR = 'datasets/walmart_amazon/'
DATASET_NAME = 'walmart_amazon'
deeper_train,deeper_test = process_data_aligned(DATASET_DIR,DATASET_NAME,ground_truth='walmart-amazon_perfectMapping.csv',
                         table1='walmart.csv',table2='amazon.csv',load_from_disk_dataset=True)
# Out:
# match_number: 1154
# len all dataset: 2308

# %%
# Caricamento strutture dati e modelli ausiliari.
EMBEDDING_FILEPATH ='embeddings/glove.840B.300d.txt'
embeddings_model, tokenizer = init_embeddings_model(EMBEDDING_FILEPATH,deeper_train,deeper_test)
# Out:
# * Costruzione indice degli embeddings.....Fatto. 2196016 embeddings totali.
# * Inizializzo il tokenizzatore.....Fatto: 12650 parole totali.
# * Preparazione della matrice di embedding.....Fatto. Dimensioni matrice embeddings: (12651, 300)
#
# °°° EMBEDDING MODEL °°°
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Tupla_A (InputLayer)            (None, None)         0
# __________________________________________________________________________________________________
# Tupla_B (InputLayer)            (None, None)         0
# __________________________________________________________________________________________________
# Embedding_lookup (Embedding)    (None, None, 300)    3795300     Tupla_A[0][0]
#                                                                  Tupla_B[0][0]
# ==================================================================================================
# Total params: 3,795,300
# Trainable params: 0
# Non-trainable params: 3,795,300
# __________________________________________________________________________________________________

# %%
from deeper.DeepER import init_DeepER_model,train_model_ER
deeper_model = init_DeepER_model(300)
dataset_name='walmart-amazon'
deeper_model = train_model_ER(deeper_train,deeper_model, 
                                      embeddings_model, 
                                      tokenizer, 
                                      pretraining=False,
                                      metric='val_accuracy',
                                      end=f'_{int(1*100)}_{dataset_name}')
# Out:
# °°° DeepER Model °°°
# Batch size: 29
# Train on 1476 samples, validate on 370 samples
# Epoch 1/64
# 1476/1476 [==============================] - 6s 4ms/step - loss: 0.3304 - accuracy: 0.8299 - val_loss: 0.1124 - val_accuracy: 0.9568
#
# Epoch 00001: val_accuracy improved from -inf to 0.95676, saving model to models/DeepER_best_model_100_walmart-amazon.h5
# Epoch 2/64
# 1476/1476 [==============================] - 4s 2ms/step - loss: 0.0855 - accuracy: 0.9756 - val_loss: 0.0958 - val_accuracy: 0.9649
#
# Epoch 00002: val_accuracy improved from 0.95676 to 0.96486, saving model to models/DeepER_best_model_100_walmart-amazon.h5
# Epoch 3/64
# 1476/1476 [==============================] - 4s 2ms/step - loss: 0.0191 - accuracy: 0.9986 - val_loss: 0.0638 - val_accuracy: 0.9811
#
# Epoch 00003: val_accuracy improved from 0.96486 to 0.98108, saving model to models/DeepER_best_model_100_walmart-amazon.h5
# Epoch 4/64
# 1476/1476 [==============================] - 4s 3ms/step - loss: 0.0088 - accuracy: 0.9980 - val_loss: 0.0589 - val_accuracy: 0.9838
#
# Epoch 00004: val_accuracy improved from 0.98108 to 0.98378, saving model to models/DeepER_best_model_100_walmart-amazon.h5
# Epoch 5/64
# 1476/1476 [==============================] - 4s 3ms/step - loss: 0.0277 - accuracy: 0.9919 - val_loss: 0.1202 - val_accuracy: 0.9595
#
# Epoch 00005: val_accuracy did not improve from 0.98378
# Epoch 6/64
# 1476/1476 [==============================] - 4s 3ms/step - loss: 0.0225 - accuracy: 0.9946 - val_loss: 0.0701 - val_accuracy: 0.9757
#
# Epoch 00006: val_accuracy did not improve from 0.98378
# Epoch 7/64
# 1476/1476 [==============================] - 4s 3ms/step - loss: 0.0150 - accuracy: 0.9966 - val_loss: 0.0796 - val_accuracy: 0.9676
#
# Epoch 00007: val_accuracy did not improve from 0.98378
# Epoch 8/64
# 1476/1476 [==============================] - 4s 3ms/step - loss: 0.0213 - accuracy: 0.9946 - val_loss: 0.1029 - val_accuracy: 0.9649
#
# Epoch 00008: val_accuracy did not improve from 0.98378
# Epoch 9/64
# 1476/1476 [==============================] - 4s 3ms/step - loss: 0.0106 - accuracy: 0.9973 - val_loss: 0.0736 - val_accuracy: 0.9784
#
# Epoch 00009: val_accuracy did not improve from 0.98378
# Epoch 10/64
# 1476/1476 [==============================] - 4s 3ms/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.0986 - val_accuracy: 0.9730
#
# Epoch 00010: val_accuracy did not improve from 0.98378
# Epoch 11/64
# 1476/1476 [==============================] - 4s 2ms/step - loss: 5.0795e-04 - accuracy: 1.0000 - val_loss: 0.1019 - val_accuracy: 0.9757
#
# Epoch 00011: val_accuracy did not improve from 0.98378
# Epoch 00011: early stopping

# %%
walmart_model = load_model('models/DeepER_best_model_100_walmart-amazon.h5')

# %%
ltable,rtable,labels = data2Inputs(deeper_train,tokenizer)
lembeddings,rembeddings = embeddings_model.predict([ltable,rtable])

# %%
import tensorflow as tf
import numpy as np

# %%
x = tf.Variable(3.0, trainable=True)
with tf.GradientTape() as tape:
    y = x**3

grad = tape.gradient(y, x)
print(type(grad))
# Out:
# <class 'tensorflow.python.framework.ops.EagerTensor'>

# %%
deeper_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Embeddings_seq_a (InputLayer)   (None, None, 300)    0
# __________________________________________________________________________________________________
# Embeddings_seq_b (InputLayer)   (None, None, 300)    0
# __________________________________________________________________________________________________
# Composition (Bidirectional)     (None, 300)          541200      Embeddings_seq_a[0][0]
#                                                                  Embeddings_seq_b[0][0]
# __________________________________________________________________________________________________
# Similarity (Lambda)             (None, 300)          0           Composition[0][0]
#                                                                  Composition[1][0]
# __________________________________________________________________________________________________
# Dense1 (Dense)                  (None, 300)          90300       Similarity[0][0]
# __________________________________________________________________________________________________
# Dense2 (Dense)                  (None, 300)          90300       Dense1[0][0]
# __________________________________________________________________________________________________
# Classification (Dense)          (None, 2)            602         Dense2[0][0]
# ==================================================================================================
# Total params: 722,402
# Trainable params: 722,402
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def _input_fn(seq1,seq2,labels):
    def generator():
        for s1, s2, l in zip(seq1,seq2,labels):
            yield {"seq_a": s1, "seq_b": s2}, l
    dataset = tf.data.Dataset.from_generator(generator,output_types=({"seq_a": tf.float32, "seq_b": tf.float32}, 
                                                                     tf.float32))
    dataset = dataset.batch(2)
    return dataset

# %%
dataset = _input_fn(lembeddings,rembeddings,labels)

# %%
lembeddings = tf.Variable(lembeddings[0:10])
rembeddings = tf.Variable(rembeddings[0:10])
with tf.GradientTape() as tape:
    prediction = deeper_model([lembeddings,rembeddings])

# %%
prediction.eval()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-ea3ffe601087> in <module>
# ----> 1 prediction.eval()
#
# ~/anaconda3/envs/testenv/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in eval(self, feed_dict, session)
#     812       A numpy array corresponding to the value of this tensor.
#     813     """
# --> 814     return _eval_using_default_session(self, feed_dict, self.graph, session)
#     815
#     816   @deprecation.deprecated(None, "Use ref() instead.")
#
# ~/anaconda3/envs/testenv/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in _eval_using_default_session(tensors, feed_dict, graph, session)
#    5310     session = get_default_session()
#    5311     if session is None:
# -> 5312       raise ValueError("Cannot evaluate tensor using `eval()`: No default "
#    5313                        "session is registered. Use `with "
#    5314                        "sess.as_default()` or pass an explicit session to "
#
# ValueError: Cannot evaluate tensor using `eval()`: No default session is registered. Use `with sess.as_default()` or pass an explicit session to `eval(session=sess)`

# %%
x = tf.constant(3.0)
with tf.GradientTape() as tape:
    tape.watch(x)
    y = x**x

print(tape.gradient(y, x).numpy()) # -> 27.0
# Out:
# 56.662533

# %%
preds
# Out:
# <tf.Tensor 'model_2_1/Classification/Softmax:0' shape=(10, 2) dtype=float32>

# %%
walmart_model.input[0] = K.variable(value=l_exampleInput)
walmart_model.input[1] = K.variable(value=r_exampleInput)
true_labels_tf = K.variable(value=labels[:10])
loss = K.binary_crossentropy(true_labels_tf,walmart_model.output)
grads = K.gradients(loss,walmart_model.input)

# %%
tf_session.run(grads,{walmart_model.input[0]:l_exampleInput,walmart_model.input[1]:r_exampleInput})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-110-a5b5f4a6b367> in <module>
# ----> 1 tf_session.run(grads,{walmart_model.input[0]:l_exampleInput,walmart_model.input[1]:r_exampleInput})
#
# ~/anaconda3/envs/testenv/lib/python3.8/site-packages/tensorflow/python/ops/variables.py in __hash__(self)
#    1077   def __hash__(self):
#    1078     if ops.Tensor._USE_EQUALITY and ops.executing_eagerly_outside_functions():  # pylint: disable=protected-access
# -> 1079       raise TypeError("Variable is unhashable. "
#    1080                       "Instead, use tensor.ref() as the key.")
#    1081     else:
#
# TypeError: Variable is unhashable. Instead, use tensor.ref() as the key.

# %%
print("Eager mode: ", tf.executing_eagerly())
# Out:
# Eager mode:  True

# %%
# !conda list
